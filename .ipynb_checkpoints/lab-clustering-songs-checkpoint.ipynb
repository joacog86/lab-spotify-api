# %% [markdown]
# # Lab | Clustering songs
#
# ## Introduction
#
# Now it's time to cluster the songs of the **hot_songs** and **not_hot_songs** databases according to the song's audio features. For this purpose, you need to consider the following questions:
#
# * Are you going to use all the audio features? I
#   * If not, which ones do you think that makes more sense to be used?
#   * It might make sense to use a dimensionality reduction technique to visualize the songs with only two features?
# * What is the optimal number of clusters (for methods that need to know this beforehand)?
# * What is the best distance to use?
# * What clustering method provides better results?
# * Does the clustering method need a transformer?
#
# ## Considerations
#
# Be aware that this process is extremely time-consuming!!! (it might take several hours on your laptop). Therefore, when testing different options, save the models into your disk in order to be able to use the best model later.  You don't want to retrain the best model again when you know what are the optimal parameters for each.
#
# To determine which clustering method performs best, you need to be practical and think about how many clusters you might want to have alongside with a [clustering metric](https://analyticsindiamag.com/a-tutorial-on-various-clustering-evaluation-metrics/) to evaluate how good or bad the songs were clustered.
# If the number of clusters is small, each cluster will be too big and generic. On the contrary, if the number of clusters is too big then each cluster will be too specific and it will be poorly populated (this also depends on how heterogeneous is your dataset).
#
# On the other hand, when you train your clustering model make sure to concatenate both databases together (ie: **hot_songs** and **not_hot_songs**) before.
# If you don't combine both datasets, the clusters obtained with the **hot_songs** will be different than the ones obtained with the **not_hot_songs**
# database even though they might have the same label because they will contain different songs. However, after this, you will not know to which original
# dataframe belongs each song. To prevent this problem, before the concatenation you can add a new column named "dataset" with a "flag" to remind yourself in which dataset was included ("Hot", "Not hot")
# each song.
#
# Finally, add a new column to the full dataset **for each clustering method with the cluster membership of each song**

# %%
#Loading the DataBase of Not Hot 100

hot100 = pd.read_csv('nothot100_slim.csv')

# %%
#Concatenating list of songs + audio features

hot100_total_df = pd.concat([hot100_df, audio_features_df], axis=1)

# %%
hot100_total_df
# Out:
#               artist                                    song  \
# 0     Britney Spears                  Oops!...I Did It Again
# 1          blink-182                    All The Small Things
# 2         Faith Hill                                 Breathe
# 3           Bon Jovi                            It's My Life
# 4             *NSYNC                             Bye Bye Bye
# ...              ...                                     ...
# 1995  Jonas Brothers                                  Sucker
# 1996    Taylor Swift                            Cruel Summer
# 1997    Blanco Brown                              The Git Up
# 1998       Sam Smith  Dancing With A Stranger (with Normani)
# 1999     Post Malone                                 Circles
#
#                                         id  danceability  energy  key  \
# 0     spotify:track:6naxalmIoLFWR0siv8dnQQ         0.751   0.834    1
# 1     spotify:track:2m1hi0nfMR9vdGC8UcrnwU         0.434   0.897    0
# 2     spotify:track:3y4LxiYMgDl4RethdzpmNe         0.529   0.496    7
# 3     spotify:track:0v1XpBHnsbkCn7iJ9Ucr1l         0.551   0.913    0
# 4     spotify:track:0fRtUt9EEkxJBdLku8EsG6         0.571   0.870    8
# ...                                    ...           ...     ...  ...
# 1995  spotify:track:22vgEDb5hykfaTwLuskFGD         0.775   0.598    2
# 1996  spotify:track:1BxfuPKGuaTgP7aM0Bbdwr         0.773   0.747    5
# 1997  spotify:track:01tA4XmJ4fGQNwti6b2hPm         0.664   0.573    5
# 1998  spotify:track:3xgT3xIlFGqZjYW9QlhJWp         0.275   0.238    9
# 1999  spotify:track:21jGcNKet2qwijlDFuPiPb         0.794   0.653    7
#
#       loudness  mode  speechiness  acousticness  ...  liveness  valence  \
# 0       -5.444     0       0.0437       0.30000  ...    0.3550    0.894
# 1       -4.918     1       0.0488       0.01030  ...    0.6120    0.684
# 2       -9.007     1       0.0290       0.17300  ...    0.2510    0.278
# 3       -4.063     0       0.0466       0.02630  ...    0.3470    0.544
# 4       -3.877     0       0.0644       0.01980  ...    0.0564    0.811
# ...        ...   ...          ...           ...  ...       ...      ...
# 1995    -7.274     1       0.0535       0.00175  ...    0.2530    0.356
# 1996    -4.061     1       0.0885       0.02420  ...    0.1090    0.801
# 1997    -6.519     1       0.0277       0.61300  ...    0.0857    0.566
# 1998   -13.119     1       0.0389       0.97700  ...    0.1450    0.257
# 1999    -7.839     1       0.1040       0.04890  ...    0.1000    0.397
#
#         tempo            type                      id  \
# 0      95.053  audio_features  6naxalmIoLFWR0siv8dnQQ
# 1     148.726  audio_features  2m1hi0nfMR9vdGC8UcrnwU
# 2     136.859  audio_features  3y4LxiYMgDl4RethdzpmNe
# 3     119.992  audio_features  0v1XpBHnsbkCn7iJ9Ucr1l
# 4     172.716  audio_features  0fRtUt9EEkxJBdLku8EsG6
# ...       ...             ...                     ...
# 1995  129.988  audio_features  0lnIJmgcUpEpe4AZACjayW
# 1996  126.014  audio_features  0ErK6K0kYr0Ow2RkPMhmMs
# 1997   76.023  audio_features  3d8y0t70g7hw2FOWl9Z4Fm
# 1998   88.980  audio_features  0fF9YHMCuv1mAQv4z5SU7L
# 1999  117.996  audio_features  3BtuIIrQlkujKPuWF2B85z
#
#                                        uri  \
# 0     spotify:track:6naxalmIoLFWR0siv8dnQQ
# 1     spotify:track:2m1hi0nfMR9vdGC8UcrnwU
# 2     spotify:track:3y4LxiYMgDl4RethdzpmNe
# 3     spotify:track:0v1XpBHnsbkCn7iJ9Ucr1l
# 4     spotify:track:0fRtUt9EEkxJBdLku8EsG6
# ...                                    ...
# 1995  spotify:track:0lnIJmgcUpEpe4AZACjayW
# 1996  spotify:track:0ErK6K0kYr0Ow2RkPMhmMs
# 1997  spotify:track:3d8y0t70g7hw2FOWl9Z4Fm
# 1998  spotify:track:0fF9YHMCuv1mAQv4z5SU7L
# 1999  spotify:track:3BtuIIrQlkujKPuWF2B85z
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/6naxalmIoLFW...
# 1     https://api.spotify.com/v1/tracks/2m1hi0nfMR9v...
# 2     https://api.spotify.com/v1/tracks/3y4LxiYMgDl4...
# 3     https://api.spotify.com/v1/tracks/0v1XpBHnsbkC...
# 4     https://api.spotify.com/v1/tracks/0fRtUt9EEkxJ...
# ...                                                 ...
# 1995  https://api.spotify.com/v1/tracks/0lnIJmgcUpEp...
# 1996  https://api.spotify.com/v1/tracks/0ErK6K0kYr0O...
# 1997  https://api.spotify.com/v1/tracks/3d8y0t70g7hw...
# 1998  https://api.spotify.com/v1/tracks/0fF9YHMCuv1m...
# 1999  https://api.spotify.com/v1/tracks/3BtuIIrQlkuj...
#
#                                            analysis_url duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/6nax...      211160
# 1     https://api.spotify.com/v1/audio-analysis/2m1h...      167067
# 2     https://api.spotify.com/v1/audio-analysis/3y4L...      250547
# 3     https://api.spotify.com/v1/audio-analysis/0v1X...      224493
# 4     https://api.spotify.com/v1/audio-analysis/0fRt...      199640
# ...                                                 ...         ...
# 1995  https://api.spotify.com/v1/audio-analysis/0lnI...      232560
# 1996  https://api.spotify.com/v1/audio-analysis/0ErK...      246240
# 1997  https://api.spotify.com/v1/audio-analysis/3d8y...      160097
# 1998  https://api.spotify.com/v1/audio-analysis/0fF9...      155167
# 1999  https://api.spotify.com/v1/audio-analysis/3Btu...      263373
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 1995               4
# 1996               4
# 1997               4
# 1998               4
# 1999               4
#
# [2000 rows x 21 columns]

# %%
hot100_total_df['H_or_N'] = 'N'

# %%
hot100_total_df.to_csv('nothot100_full.csv', index=False)

# %% [markdown]
# ## Loading Hot and NotHot Datasets

# %%
hot100 = pd.read_csv('hot100_full.csv')
nothot100 = pd.read_csv('nothot100_full.csv')

# %%
total_df = pd.concat([hot100, nothot100])

# %%
total_df
# Out:
#                                     artist  \
# 0                              Jack Harlow
# 1                             Taylor Swift
# 2                               Tate McRae
# 3                                 Doja Cat
# 4     Zach Bryan Featuring Kacey Musgraves
# ...                                    ...
# 1995                        Jonas Brothers
# 1996                          Taylor Swift
# 1997                          Blanco Brown
# 1998                             Sam Smith
# 1999                           Post Malone
#
#                                         song  \
# 0                                Lovin On Me
# 1                               Cruel Summer
# 2                                     Greedy
# 3                         Paint The Town Red
# 4                      I Remember Everything
# ...                                      ...
# 1995                                  Sucker
# 1996                            Cruel Summer
# 1997                              The Git Up
# 1998  Dancing With A Stranger (with Normani)
# 1999                                 Circles
#
#                                         id  danceability  energy  key  \
# 0     spotify:track:4xhsWYTOGcal8zt0J161CU         0.943   0.558    2
# 1     spotify:track:1BxfuPKGuaTgP7aM0Bbdwr         0.552   0.702    9
# 2     spotify:track:3rUGC1vUpkDG9CZFHMur1t         0.750   0.733    6
# 3     spotify:track:2IGMVunIBsBLtEQyoI1Mu7         0.868   0.538    5
# 4     spotify:track:4KULAymBBJcPRpk1yO4dOG         0.429   0.453    0
# ...                                    ...           ...     ...  ...
# 1995  spotify:track:22vgEDb5hykfaTwLuskFGD         0.775   0.598    2
# 1996  spotify:track:1BxfuPKGuaTgP7aM0Bbdwr         0.773   0.747    5
# 1997  spotify:track:01tA4XmJ4fGQNwti6b2hPm         0.664   0.573    5
# 1998  spotify:track:3xgT3xIlFGqZjYW9QlhJWp         0.275   0.238    9
# 1999  spotify:track:21jGcNKet2qwijlDFuPiPb         0.794   0.653    7
#
#       loudness  mode  speechiness  acousticness  ...  valence    tempo  \
# 0       -4.911     1       0.0568       0.00260  ...    0.606  104.983
# 1       -5.707     1       0.1570       0.11700  ...    0.564  169.994
# 2       -3.180     0       0.0319       0.25600  ...    0.844  111.018
# 3       -8.603     1       0.1740       0.26900  ...    0.732   99.968
# 4       -7.746     1       0.0459       0.55400  ...    0.155   77.639
# ...        ...   ...          ...           ...  ...      ...      ...
# 1995    -7.274     1       0.0535       0.00175  ...    0.356  129.988
# 1996    -4.061     1       0.0885       0.02420  ...    0.801  126.014
# 1997    -6.519     1       0.0277       0.61300  ...    0.566   76.023
# 1998   -13.119     1       0.0389       0.97700  ...    0.257   88.980
# 1999    -7.839     1       0.1040       0.04890  ...    0.397  117.996
#
#                 type                    id.1  \
# 0     audio_features  4xhsWYTOGcal8zt0J161CU
# 1     audio_features  1BxfuPKGuaTgP7aM0Bbdwr
# 2     audio_features  3rUGC1vUpkDG9CZFHMur1t
# 3     audio_features  2IGMVunIBsBLtEQyoI1Mu7
# 4     audio_features  4KULAymBBJcPRpk1yO4dOG
# ...              ...                     ...
# 1995  audio_features  0lnIJmgcUpEpe4AZACjayW
# 1996  audio_features  0ErK6K0kYr0Ow2RkPMhmMs
# 1997  audio_features  3d8y0t70g7hw2FOWl9Z4Fm
# 1998  audio_features  0fF9YHMCuv1mAQv4z5SU7L
# 1999  audio_features  3BtuIIrQlkujKPuWF2B85z
#
#                                        uri  \
# 0     spotify:track:4xhsWYTOGcal8zt0J161CU
# 1     spotify:track:1BxfuPKGuaTgP7aM0Bbdwr
# 2     spotify:track:3rUGC1vUpkDG9CZFHMur1t
# 3     spotify:track:2IGMVunIBsBLtEQyoI1Mu7
# 4     spotify:track:4KULAymBBJcPRpk1yO4dOG
# ...                                    ...
# 1995  spotify:track:0lnIJmgcUpEpe4AZACjayW
# 1996  spotify:track:0ErK6K0kYr0Ow2RkPMhmMs
# 1997  spotify:track:3d8y0t70g7hw2FOWl9Z4Fm
# 1998  spotify:track:0fF9YHMCuv1mAQv4z5SU7L
# 1999  spotify:track:3BtuIIrQlkujKPuWF2B85z
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/4xhsWYTOGcal...
# 1     https://api.spotify.com/v1/tracks/1BxfuPKGuaTg...
# 2     https://api.spotify.com/v1/tracks/3rUGC1vUpkDG...
# 3     https://api.spotify.com/v1/tracks/2IGMVunIBsBL...
# 4     https://api.spotify.com/v1/tracks/4KULAymBBJcP...
# ...                                                 ...
# 1995  https://api.spotify.com/v1/tracks/0lnIJmgcUpEp...
# 1996  https://api.spotify.com/v1/tracks/0ErK6K0kYr0O...
# 1997  https://api.spotify.com/v1/tracks/3d8y0t70g7hw...
# 1998  https://api.spotify.com/v1/tracks/0fF9YHMCuv1m...
# 1999  https://api.spotify.com/v1/tracks/3BtuIIrQlkuj...
#
#                                            analysis_url duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/4xhs...      138411
# 1     https://api.spotify.com/v1/audio-analysis/1Bxf...      178427
# 2     https://api.spotify.com/v1/audio-analysis/3rUG...      131872
# 3     https://api.spotify.com/v1/audio-analysis/2IGM...      231750
# 4     https://api.spotify.com/v1/audio-analysis/4KUL...      227196
# ...                                                 ...         ...
# 1995  https://api.spotify.com/v1/audio-analysis/0lnI...      232560
# 1996  https://api.spotify.com/v1/audio-analysis/0ErK...      246240
# 1997  https://api.spotify.com/v1/audio-analysis/3d8y...      160097
# 1998  https://api.spotify.com/v1/audio-analysis/0fF9...      155167
# 1999  https://api.spotify.com/v1/audio-analysis/3Btu...      263373
#
#      time_signature  H_or_N
# 0                 4       H
# 1                 4       H
# 2                 1       H
# 3                 4       H
# 4                 4       H
# ...             ...     ...
# 1995              4       N
# 1996              4       N
# 1997              4       N
# 1998              4       N
# 1999              4       N
#
# [2100 rows x 22 columns]

# %%
total_df.to_csv('full_data.csv', index=False)

# %% [markdown]
# # Selecting Features

# %%
X = total_df.select_dtypes(include = np.number)

# %%
X = X.drop({'mode', 'duration_ms','time_signature'}, axis=1)

# %%
X = X.reset_index(drop=True)
X
# Out:
#       danceability  energy  key  loudness  speechiness  acousticness  \
# 0            0.943   0.558    2    -4.911       0.0568       0.00260
# 1            0.552   0.702    9    -5.707       0.1570       0.11700
# 2            0.750   0.733    6    -3.180       0.0319       0.25600
# 3            0.868   0.538    5    -8.603       0.1740       0.26900
# 4            0.429   0.453    0    -7.746       0.0459       0.55400
# ...            ...     ...  ...       ...          ...           ...
# 2095         0.775   0.598    2    -7.274       0.0535       0.00175
# 2096         0.773   0.747    5    -4.061       0.0885       0.02420
# 2097         0.664   0.573    5    -6.519       0.0277       0.61300
# 2098         0.275   0.238    9   -13.119       0.0389       0.97700
# 2099         0.794   0.653    7    -7.839       0.1040       0.04890
#
#       instrumentalness  liveness  valence    tempo
# 0             0.000002    0.0937    0.606  104.983
# 1             0.000021    0.1050    0.564  169.994
# 2             0.000000    0.1140    0.844  111.018
# 3             0.000003    0.0901    0.732   99.968
# 4             0.000002    0.1020    0.155   77.639
# ...                ...       ...      ...      ...
# 2095          0.000004    0.2530    0.356  129.988
# 2096          0.000009    0.1090    0.801  126.014
# 2097          0.000363    0.0857    0.566   76.023
# 2098          0.912000    0.1450    0.257   88.980
# 2099          0.000049    0.1000    0.397  117.996
#
# [2100 rows x 10 columns]

# %% [markdown]
# # Dimensionality Reduction

# %%
# Dimensionality Reduction

import numpy as np
import pandas as pd
from sklearn import datasets # sklearn comes with some toy datasets to practise
from sklearn.preprocessing import StandardScaler

# %%
total_df.describe()
# Out:
#        danceability       energy          key     loudness         mode  \
# count   2100.000000  2100.000000  2100.000000  2100.000000  2100.000000
# mean       0.665100     0.707474     5.410000    -5.783525     0.567619
# std        0.142213     0.166388     3.615381     2.652679     0.495525
# min        0.000000     0.000050     0.000000   -39.264000     0.000000
# 25%        0.574000     0.608000     2.000000    -6.730250     0.000000
# 50%        0.674000     0.730500     6.000000    -5.368000     1.000000
# 75%        0.763000     0.834000     8.000000    -4.205500     1.000000
# max        0.975000     0.997000    11.000000     0.836000     1.000000
#
#        speechiness  acousticness  instrumentalness     liveness      valence  \
# count  2100.000000   2100.000000       2100.000000  2100.000000  2100.000000
# mean      0.102778      0.146547          0.027393     0.181648     0.541475
# std       0.096477      0.200268          0.131568     0.142002     0.225162
# min       0.000000      0.000010          0.000000     0.021500     0.000000
# 25%       0.039500      0.014975          0.000000     0.090100     0.371000
# 50%       0.059350      0.060150          0.000000     0.125000     0.550500
# 75%       0.126000      0.193000          0.000084     0.237000     0.721250
# max       0.530000      0.989000          0.985000     0.971000     0.974000
#
#              tempo    duration_ms  time_signature
# count  2100.000000    2100.000000     2100.000000
# mean    120.097899  226517.265714        3.982381
# std      27.210620   42774.728020        0.254870
# min       0.000000   60720.000000        0.000000
# 25%      98.993500  201252.750000        4.000000
# 50%     120.021500  222333.500000        4.000000
# 75%     135.027750  247450.250000        4.000000
# max     210.857000  515867.000000        5.000000

# %% [markdown]
# ## Scaling

# %%
import pickle

scaler = StandardScaler()
scaler.fit(X)
X_scaled = scaler.transform(X)
filename = "recommender_scaler.pickle" # Path with filename

with open(filename, "wb") as file:
        pickle.dump(scaler,file)

X_scaled_df = pd.DataFrame(X_scaled, columns = X.columns)
display(X.head())
print()
display(X_scaled_df.head())
# Out:
#    danceability  energy  key  loudness  speechiness  acousticness  \
# 0         0.943   0.558    2    -4.911       0.0568        0.0026
# 1         0.552   0.702    9    -5.707       0.1570        0.1170
# 2         0.750   0.733    6    -3.180       0.0319        0.2560
# 3         0.868   0.538    5    -8.603       0.1740        0.2690
# 4         0.429   0.453    0    -7.746       0.0459        0.5540
#
#    instrumentalness  liveness  valence    tempo
# 0          0.000002    0.0937    0.606  104.983
# 1          0.000021    0.1050    0.564  169.994
# 2          0.000000    0.1140    0.844  111.018
# 3          0.000003    0.0901    0.732   99.968
# 4          0.000002    0.1020    0.155   77.639
#    danceability    energy       key  loudness  speechiness  acousticness  \
# 0      1.954576 -0.898561 -0.943417  0.329001    -0.476684     -0.718942
# 1     -0.795475 -0.032907  0.993216  0.028855     0.562148     -0.147571
# 2      0.597134  0.153450  0.163231  0.981704    -0.734837      0.546665
# 3      1.427072 -1.018791 -0.113431 -1.063131     0.738397      0.611594
# 4     -1.660581 -1.529768 -1.496741 -0.739985    -0.589691      2.035028
#
#    instrumentalness  liveness   valence     tempo
# 0         -0.208238 -0.619492  0.286640 -0.555610
# 1         -0.208098 -0.539897  0.100063  1.834136
# 2         -0.208255 -0.476502  1.343908 -0.333769
# 3         -0.208230 -0.644850  0.846370 -0.739957
# 4         -0.208240 -0.561028 -1.716840 -1.560751

# %%
X_scaled_df.describe()
# Out:
#        danceability        energy           key      loudness   speechiness  \
# count  2.100000e+03  2.100000e+03  2.100000e+03  2.100000e+03  2.100000e+03
# mean  -1.624098e-16 -9.304726e-17 -6.597897e-17 -1.218073e-16  4.398598e-17
# std    1.000238e+00  1.000238e+00  1.000238e+00  1.000238e+00  1.000238e+00
# min   -4.677900e+00 -4.252673e+00 -1.496741e+00 -1.262439e+01 -1.065563e+00
# 25%   -6.407407e-01 -5.979866e-01 -9.434170e-01 -3.569789e-01 -6.560431e-01
# 50%    6.259706e-02  1.384209e-01  1.632305e-01  1.566809e-01 -4.502465e-01
# 75%    6.885677e-01  7.606100e-01  7.165543e-01  5.950216e-01  2.407531e-01
# max    2.179644e+00  1.740483e+00  1.546540e+00  2.496006e+00  4.429258e+00
#
#        acousticness  instrumentalness      liveness       valence  \
# count  2.100000e+03      2.100000e+03  2.100000e+03  2.100000e+03
# mean   6.428720e-17     -7.612958e-18 -1.624098e-16 -5.413659e-17
# std    1.000238e+00      1.000238e+00  1.000238e+00  1.000238e+00
# min   -7.318802e-01     -2.082551e-01 -1.128055e+00 -2.405398e+00
# 25%   -6.571354e-01     -2.082551e-01 -6.448496e-01 -7.573023e-01
# 50%   -4.315086e-01     -2.082551e-01 -3.990205e-01  4.009160e-02
# 75%    2.320115e-01     -2.076184e-01  3.898870e-01  7.986153e-01
# max    4.207638e+00      7.280166e+00  5.560048e+00  1.921408e+00
#
#               tempo
# count  2.100000e+03
# mean  -6.090366e-17
# std    1.000238e+00
# min   -4.414692e+00
# 25%   -7.757789e-01
# 50%   -2.808344e-03
# 75%    5.488081e-01
# max    3.336224e+00

# %% [markdown]
# ## PCA

# %%
#PCA

from sklearn.decomposition import PCA

# When we create an instance of PCA, we can specify how many principal components we want to extract.
# However, as we don't know beforehand how much variance it will explain each principal component it's
# allways better to not set the option "n_components" to a given integer number.

pca = PCA()
pca.fit(X_scaled_df)
principal_components = pca.transform(X_scaled_df)
principal_components_df = pd.DataFrame(principal_components, columns=['PCA_'+ str(i) for i in range(1,X_scaled_df.shape[1]+1)])
principal_components_df.head()
# Out:
#       PCA_1     PCA_2     PCA_3     PCA_4     PCA_5     PCA_6     PCA_7  \
# 0 -0.338740 -1.709196 -0.827048 -0.766328  0.816929 -0.455972  0.170070
# 1 -0.216796  0.722584  1.003640  1.620775 -0.369936 -0.991079 -0.312769
# 2 -0.830786 -1.043829 -0.975965  0.244533 -0.029754  0.106245 -1.007228
# 3  0.892972 -2.352819  0.379333 -0.395769  0.056696 -0.233744 -0.171381
# 4  3.189574  0.862240 -1.267266 -1.899951 -0.376375 -0.838769 -0.019359
#
#       PCA_8     PCA_9    PCA_10
# 0 -1.296522 -0.304757 -0.450271
# 1  0.057470  0.424617 -0.252931
# 2  0.520650 -0.371735 -0.411355
# 3 -0.083890  0.321576  0.169056
# 4  1.011364 -0.281539 -0.189470

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.25142649 0.14344329 0.10918168 0.10320639 0.09734563 0.09348005
#  0.07316725 0.06309199 0.04384817 0.02180906]

# %%
cumulated_explained_variance_ratio = [sum(pca.explained_variance_ratio_[0:i+1]) for i,value in enumerate(pca.explained_variance_ratio_)]
cumulated_explained_variance_ratio
# Out:
# [0.2514264890029777,
#  0.39486977572454995,
#  0.5040514542203742,
#  0.6072578466800511,
#  0.7046034787373834,
#  0.798083526992683,
#  0.8712507786165221,
#  0.9343427651180909,
#  0.9781909375081762,
#  1.0]

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1,2, figsize=(10,5))
ax[0].plot(np.arange(1,11), pca.explained_variance_ratio_)
ax[0].set_xlabel("Principal component")
ax[0].set_title("Variance explained by each Principal Component")
ax[1].plot(np.arange(1,11),cumulated_explained_variance_ratio)
ax[1].set_title("Acumulated variance explained by Principal Components")
ax[1].set_xlabel("Number of Principal components")
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(principal_components_df['PCA_1'],principal_components_df['PCA_2'])
ax.set_xlabel("PCA_1")
ax.set_ylabel("PCA_2")
plt.show()

# %%
#PCA doesnt work

# %% [markdown]
# ## ISOMAP

# %%
#ISOMAP

from sklearn.manifold import Isomap

iso = Isomap(n_neighbors=12, n_components=2)
iso.fit(X)
X_isomap_transformed = iso.transform(X)
X_isomap_transformed_df = pd.DataFrame(X_isomap_transformed, columns=["ISO_1","ISO_2"])
X_isomap_transformed_df.head()
# Out:
#        ISO_1     ISO_2
# 0  16.890659  6.589845
# 1 -56.231819 -6.614025
# 2  10.124884  0.054458
# 3  22.707105  2.297012
# 4  48.329554  6.276096

# %%
fig, ax = plt.subplots()
ax.scatter(X_isomap_transformed_df['ISO_1'],X_isomap_transformed_df['ISO_2'])
ax.set_xlabel("ISO_1")
ax.set_ylabel("ISO_2")
plt.show()

# %% [markdown]
# ## TSNE

# %%
#TSNE

from sklearn.manifold import TSNE

tsne = TSNE(n_components=2, learning_rate=100, init='random', perplexity=40, random_state=12)

X_tsne_transformed = tsne.fit_transform(X)
X_tsne_transformed_df = pd.DataFrame(X_tsne_transformed, columns=["TSNE_1","TSNE_2"])
X_tsne_transformed_df.head()
# Out:
#       TSNE_1     TSNE_2
# 0  29.369286 -25.379694
# 1  -0.878528  46.308193
# 2   7.412775 -29.205271
# 3  25.681490 -14.987667
# 4  43.142448  24.723066

# %%
fig, ax = plt.subplots()
ax.scatter(X_tsne_transformed_df['TSNE_1'],X_tsne_transformed_df['TSNE_2'])
ax.set_xlabel("TSNE_1")
ax.set_ylabel("TSNE_2")
plt.show()

# %% [markdown]
# ## UMAP

# %%
#UMAP

from umap import UMAP

reducer = UMAP(n_components=2,random_state=42)
reducer.fit(X)

X_umap_transformed = reducer.transform(X)
X_umap_transformed_df = pd.DataFrame(X_umap_transformed, columns=["UMAP_1","UMAP_2"])
X_umap_transformed_df.head()
# Out:
# C:\Users\joaco\anaconda3\Lib\site-packages\umap\umap_.py:1943: UserWarning: n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
#       UMAP_1     UMAP_2
# 0  -1.755563   2.889598
# 1  14.358665  11.829076
# 2  -2.099702  -1.052738
# 3  -2.747906   4.868352
# 4   0.129492  13.578428

# %%
fig, ax = plt.subplots()
ax.scatter(X_umap_transformed_df['UMAP_1'],X_umap_transformed_df['UMAP_2'])
ax.set_xlabel("UMAP_1")
ax.set_ylabel("UMAP_2")
plt.show()

# %% [markdown]
# # Clustering

# %% [markdown]
# ## K-Mean

# %%
# Now we have to clusterize

import pandas as pd
from sklearn import datasets # sklearn comes with some toy datasets to practise
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
X_scaled_df.describe()
# Out:
#        danceability        energy           key      loudness   speechiness  \
# count  2.100000e+03  2.100000e+03  2.100000e+03  2.100000e+03  2.100000e+03
# mean  -1.624098e-16 -9.304726e-17 -6.597897e-17 -1.218073e-16  4.398598e-17
# std    1.000238e+00  1.000238e+00  1.000238e+00  1.000238e+00  1.000238e+00
# min   -4.677900e+00 -4.252673e+00 -1.496741e+00 -1.262439e+01 -1.065563e+00
# 25%   -6.407407e-01 -5.979866e-01 -9.434170e-01 -3.569789e-01 -6.560431e-01
# 50%    6.259706e-02  1.384209e-01  1.632305e-01  1.566809e-01 -4.502465e-01
# 75%    6.885677e-01  7.606100e-01  7.165543e-01  5.950216e-01  2.407531e-01
# max    2.179644e+00  1.740483e+00  1.546540e+00  2.496006e+00  4.429258e+00
#
#        acousticness  instrumentalness      liveness       valence  \
# count  2.100000e+03      2.100000e+03  2.100000e+03  2.100000e+03
# mean   6.428720e-17     -7.612958e-18 -1.624098e-16 -5.413659e-17
# std    1.000238e+00      1.000238e+00  1.000238e+00  1.000238e+00
# min   -7.318802e-01     -2.082551e-01 -1.128055e+00 -2.405398e+00
# 25%   -6.571354e-01     -2.082551e-01 -6.448496e-01 -7.573023e-01
# 50%   -4.315086e-01     -2.082551e-01 -3.990205e-01  4.009160e-02
# 75%    2.320115e-01     -2.076184e-01  3.898870e-01  7.986153e-01
# max    4.207638e+00      7.280166e+00  5.560048e+00  1.921408e+00
#
#               tempo
# count  2.100000e+03
# mean  -6.090366e-17
# std    1.000238e+00
# min   -4.414692e+00
# 25%   -7.757789e-01
# 50%   -2.808344e-03
# 75%    5.488081e-01
# max    3.336224e+00

# %%
#We pick random clusters

kmeans = KMeans(n_clusters=6, random_state=1234)
kmeans.fit(X_scaled_df)
# Out:
# C:\Users\joaco\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=6, random_state=1234)

# %%
clusters = kmeans.predict(X_scaled_df)
#clusters
pd.Series(clusters).value_counts().sort_index() # Number of wines in each cluster
# Out:
# 0    250
# 1    593
# 2    703
# 3    215
# 4     56
# 5    283
# Name: count, dtype: int64

# %%
#X_df = pd.DataFrame(X)
X["cluster"] = clusters
X.head()
# Out:
#    danceability  energy  key  loudness  speechiness  acousticness  \
# 0         0.943   0.558    2    -4.911       0.0568        0.0026
# 1         0.552   0.702    9    -5.707       0.1570        0.1170
# 2         0.750   0.733    6    -3.180       0.0319        0.2560
# 3         0.868   0.538    5    -8.603       0.1740        0.2690
# 4         0.429   0.453    0    -7.746       0.0459        0.5540
#
#    instrumentalness  liveness  valence    tempo  cluster
# 0          0.000002    0.0937    0.606  104.983        2
# 1          0.000021    0.1050    0.564  169.994        1
# 2          0.000000    0.1140    0.844  111.018        2
# 3          0.000003    0.0901    0.732   99.968        5
# 4          0.000002    0.1020    0.155   77.639        3

# %%
#To get a sample of 5, for recommendation, hay que darle input de una cancion, buscar el cluster y usar ese para buscar otros

X[X['cluster'] == 5].sample(5)
#sample 5 to get 5 recommendations!
# Out:
#       danceability  energy  key  loudness  speechiness  acousticness  \
# 1800         0.638   0.523    1    -6.664        0.357       0.00454
# 509          0.783   0.916    1    -3.344        0.415       0.11000
# 781          0.862   0.742    7    -4.722        0.222       0.00376
# 890          0.697   0.860   11    -5.181        0.430       0.03680
# 1243         0.364   0.752    2    -5.429        0.304       0.00070
#
#       instrumentalness  liveness  valence    tempo  cluster
# 1800           0.00000    0.0842    0.422  139.913        5
# 509            0.00000    0.0746    0.695   95.321        5
# 781            0.00855    0.1030    0.511  127.910        5
# 890            0.00000    0.0721    0.433  160.895        5
# 1243           0.00000    0.3180    0.606   79.119        5

# %%
# Determine the features of a "typical" cluster del song recommender
# estos van a ser los tipicos songs de cada cluster (de los 7 que se generaron)
pd.DataFrame(scaler.inverse_transform(kmeans.cluster_centers_), columns=X.columns[:-1])
# Out:
#    danceability    energy       key   loudness  speechiness  acousticness  \
# 0      0.624328  0.809004  5.412000  -4.760640     0.104637      0.073609
# 1      0.581459  0.733528  4.790894  -5.319354     0.065729      0.075418
# 2      0.748267  0.754866  5.918919  -5.000777     0.071746      0.109014
# 3      0.588684  0.441867  5.702326  -8.796414     0.066493      0.521954
# 4      0.605929  0.565338  5.125000 -11.491393     0.066066      0.332093
# 5      0.739548  0.675375  5.275618  -6.185770     0.290689      0.131339
#
#    instrumentalness  liveness   valence       tempo
# 0          0.006036  0.469008  0.601784  124.702648
# 1          0.008496  0.151773  0.362762  127.113639
# 2          0.006391  0.127439  0.725168  115.562385
# 3          0.009414  0.149300  0.358788  109.840981
# 4          0.775857  0.145009  0.396379  123.319821
# 5          0.003580  0.156884  0.573866  119.750739

# %%
#Using KMEAN Manual, so as to find out the K

kmeans.inertia_
# Out:
# 12547.431784264101

# %%
kmeans2 = KMeans(n_clusters=8, # Number of clusters/groups
                init="random",
                n_init=3, # Number starting locations for the centroids
                max_iter=2, # Maximum amount of times the centroid's locations are going to be updated (default value = 300)
                tol=0, # Maximum displacement of the centroid's location
                algorithm="full",
                random_state=1234)

kmeans2.fit(X_scaled_df)
print(kmeans2.inertia_)
# Out:
# 12469.30683376839
# C:\Users\joaco\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: algorithm='full' is deprecated, it will be removed in 1.3. Using 'lloyd' instead.
#   warnings.warn(

# %%
# Buscando el valor de K

K = range(2, 21)

inertia = []
silhouette = []

for k in K:
    print("Training a K-Means model with {} clusters! ".format(k))
    print()
    kmeans = KMeans(n_clusters=k,
                    random_state=1234,
                    verbose=1)
    kmeans.fit(X_scaled_df)

    filename = "kmeans_" + str(k) + ".pickle" # Path with filename # kmeans_n.pickle
    with open(filename, "wb") as file:
        pickle.dump(kmeans,file)

    inertia.append(kmeans.inertia_)
    silhouette.append(silhouette_score(X_scaled_df, kmeans.predict(X_scaled_df)))


import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(1,2,figsize=(16,8))
ax[0].plot(K, inertia, 'bx-')
ax[0].set_xlabel('k')
ax[0].set_ylabel('inertia')
ax[0].set_xticks(np.arange(min(K), max(K)+1, 1.0))
ax[0].set_title('Elbow Method showing the optimal k')
ax[1].plot(K, silhouette, 'bx-')
ax[1].set_xlabel('k')
ax[1].set_ylabel('silhouette score')
ax[1].set_xticks(np.arange(min(K), max(K)+1, 1.0))
ax[1].set_title('Silhouette Method showing the optimal k')
# Out:
# Training a K-Means model with 2 clusters!
#
# Initialization complete
# Iteration 0, inertia 27463.780395034813.
# Iteration 1, inertia 19505.784867039718.
# Iteration 2, inertia 19310.295749897585.
# Iteration 3, inertia 19195.873209218604.
# Iteration 4, inertia 19122.45852644493.
# Iteration 5, inertia 19046.893972337577.
# Iteration 6, inertia 18951.913575104696.
# Iteration 7, inertia 18852.732743865352.
# Iteration 8, inertia 18731.77742958642.
# Iteration 9, inertia 18590.02690378225.
# Iteration 10, inertia 18443.156575389414.
# Iteration 11, inertia 18332.933851417107.
# Iteration 12, inertia 18233.14198976603.
# Iteration 13, inertia 18163.774735023806.
# Iteration 14, inertia 18112.096262002022.
# Iteration 15, inertia 18093.004935266115.
# Iteration 16, inertia 18081.50837979935.
# Iteration 17, inertia 18075.34503041614.
# Iteration 18, inertia 18072.340856335948.
# Iteration 19, inertia 18069.202748882475.
# Iteration 20, inertia 18067.185262568568.
# Iteration 21, inertia 18066.123556251678.
# Iteration 22, inertia 18065.782043516316.
# Iteration 23, inertia 18065.676662110123.
# Converged at iteration 23: center shift 6.751614679939708e-05 within tolerance 9.999999999999986e-05.
# Initialization complete
# Iteration 17, inertia 8264.045182616479.
# Iteration 18, inertia 8259.562348648182.
# Iteration 19, inertia 8255.35209024749.
# Iteration 20, inertia 8251.846836547884.
# Iteration 21, inertia 8249.909186943853.
# Iteration 22, inertia 8248.466452599603.
# Iteration 23, inertia 8245.648611675613.
# Iteration 24, inertia 8242.830421990839.
# Iteration 25, inertia 8238.129588183478.
# Iteration 26, inertia 8234.837525665082.
# Iteration 27, inertia 8231.04051390645.
# Iteration 28, inertia 8227.718098485373.
# Iteration 29, inertia 8225.593123921986.
# Iteration 30, inertia 8222.650342556473.
# Iteration 31, inertia 8219.855203913266.
# Iteration 32, inertia 8218.886113371991.
# Iteration 33, inertia 8217.66715999129.
# Iteration 34, inertia 8216.53061201988.
# Iteration 35, inertia 8215.470471989209.
# Iteration 36, inertia 8214.962013423303.
# Converged at iteration 36: strict convergence.
# Text(0.5, 1.0, 'Silhouette Method showing the optimal k')

# %%
#There is no clear elbow!,or maybe its k=3 because of the silhouette?
#Should we run  the K-Mean with the Dimensionlity Reduction?

#What you do is we run the ISOMAP and the UMAP again with K=6 that is the number of clusters it seems to be optimized in K-Mean

# %% [markdown]
# ### ISOMAP with clusters = 6

# %%
#ISOMAP with clusters=3


from sklearn.manifold import Isomap

iso = Isomap(n_neighbors=5, n_components=2)
iso.fit(X)
X_isomap_transformed = iso.transform(X)
X_isomap_transformed_df = pd.DataFrame(X_isomap_transformed, columns=["ISO_1","ISO_2"])
X_isomap_transformed_df.head()
# Out:
#        ISO_1     ISO_2
# 0  21.174794  1.659886
# 1 -70.252097 -5.439598
# 2  11.846830  0.041029
# 3  30.828001  2.397492
# 4  56.170170 -3.634494

# %%
fig, ax = plt.subplots()
ax.scatter(X_isomap_transformed_df['ISO_1'],X_isomap_transformed_df['ISO_2'])
ax.set_xlabel("ISO_1")
ax.set_ylabel("ISO_2")
plt.show()

# %%
X
# Out:
#       danceability  energy  key  loudness  speechiness  acousticness  \
# 0            0.943   0.558    2    -4.911       0.0568       0.00260
# 1            0.552   0.702    9    -5.707       0.1570       0.11700
# 2            0.750   0.733    6    -3.180       0.0319       0.25600
# 3            0.868   0.538    5    -8.603       0.1740       0.26900
# 4            0.429   0.453    0    -7.746       0.0459       0.55400
# ...            ...     ...  ...       ...          ...           ...
# 2095         0.775   0.598    2    -7.274       0.0535       0.00175
# 2096         0.773   0.747    5    -4.061       0.0885       0.02420
# 2097         0.664   0.573    5    -6.519       0.0277       0.61300
# 2098         0.275   0.238    9   -13.119       0.0389       0.97700
# 2099         0.794   0.653    7    -7.839       0.1040       0.04890
#
#       instrumentalness  liveness  valence    tempo  cluster
# 0             0.000002    0.0937    0.606  104.983        2
# 1             0.000021    0.1050    0.564  169.994        1
# 2             0.000000    0.1140    0.844  111.018        2
# 3             0.000003    0.0901    0.732   99.968        5
# 4             0.000002    0.1020    0.155   77.639        3
# ...                ...       ...      ...      ...      ...
# 2095          0.000004    0.2530    0.356  129.988        1
# 2096          0.000009    0.1090    0.801  126.014        2
# 2097          0.000363    0.0857    0.566   76.023        3
# 2098          0.912000    0.1450    0.257   88.980        4
# 2099          0.000049    0.1000    0.397  117.996        2
#
# [2100 rows x 11 columns]

# %%
#It looks much better, though the clusters and not that clear i think

# %% [markdown]
# ### UMAP = 2

# %%
#UMAP

from umap import UMAP

reducer = UMAP(n_components=2,random_state=42)
reducer.fit(X)

X_umap_transformed = reducer.transform(X)
X_umap_transformed_df = pd.DataFrame(X_umap_transformed, columns=["UMAP_1","UMAP_2"])
X_umap_transformed_df.head()
# Out:
# C:\Users\joaco\anaconda3\Lib\site-packages\umap\umap_.py:1943: UserWarning: n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
#       UMAP_1     UMAP_2
# 0  -3.796060   8.062485
# 1  13.236357   0.661808
# 2  -1.817169  10.173134
# 3  -2.661006   3.860967
# 4  -2.188247  -3.334076

# %%
fig, ax = plt.subplots()
ax.scatter(X_umap_transformed_df['UMAP_1'],X_umap_transformed_df['UMAP_2'])
ax.set_xlabel("UMAP_1")
ax.set_ylabel("UMAP_2")
plt.show()

# %% [markdown]
# ## DBSCAN

# %%
#Trying DBSCAN

import pandas as pd
import numpy as np
from sklearn.datasets import make_classification
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from scipy.spatial.distance import euclidean
from sklearn.metrics import silhouette_score, calinski_harabasz_score
from kneed import KneeLocator
import matplotlib.pyplot as plt
import seaborn as sns
import colorcet as cc
import time
import pickle
#from dbcv import *

# %%
# Creating the clustering model
model = DBSCAN() # Default values are: eps=0.5, min_samples=5
# fit model and predict clusters
yhat = model.fit_predict(X_umap_transformed_df) # .fit(X_scaled_df)

# %%
yhat
# Out:
# array([0, 1, 2, ..., 4, 3, 2], dtype=int64)

# %%
print("The Silhouette score of the model is: ",round(silhouette_score(X_scaled_df, model.fit_predict(X_scaled_df)),2))
print("The Calinksi-Harabasz score of the model is: ",round(calinski_harabasz_score(X_scaled_df, model.fit_predict(X_scaled_df)),2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[267], line 1
# ----> 1 print("The Silhouette score of the model is: ",round(silhouette_score(X_scaled_df, model.fit_predict(X_scaled_df)),2))
#       2 print("The Calinksi-Harabasz score of the model is: ",round(calinski_harabasz_score(X_scaled_df, model.fit_predict(X_scaled_df)),2))
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File ~\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py:131, in silhouette_score(X, labels, metric, sample_size, random_state, **kwds)
#     129     else:
#     130         X, labels = X[indices], labels[indices]
# --> 131 return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:184, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     182 global_skip_validation = get_config()["skip_parameter_validation"]
#     183 if global_skip_validation:
# --> 184     return func(*args, **kwargs)
#     186 func_sig = signature(func)
#     188 # Map *args/**kwargs to the function signature
#
# File ~\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py:277, in silhouette_samples(X, labels, metric, **kwds)
#     275 n_samples = len(labels)
#     276 label_freqs = np.bincount(labels)
# --> 277 check_number_of_labels(len(le.classes_), n_samples)
#     279 kwds["metric"] = metric
#     280 reduce_func = functools.partial(
#     281     _silhouette_reduce, labels=labels, label_freqs=label_freqs
#     282 )
#
# File ~\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py:37, in check_number_of_labels(n_labels, n_samples)
#      26 """Check that number of labels are valid.
#      27
#      28 Parameters
#    (...)
#      34     Number of samples.
#      35 """
#      36 if not 1 < n_labels < n_samples:
# ---> 37     raise ValueError(
#      38         "Number of labels is %d. Valid values are 2 to n_samples - 1 (inclusive)"
#      39         % n_labels
#      40     )
#
# ValueError: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
